# %%
pip install flickrapi
# Out:
# Collecting flickrapi
#   Downloading https://files.pythonhosted.org/packages/76/d7/291b7f0f02cf0f59460f7bcc15192905b4c61e13b9fb9263ee86b0a5f647/flickrapi-2.4.0-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.4.0
#   Using cached https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Collecting requests-toolbelt>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
# Requirement already satisfied: six>=1.5.2 in c:\anaconda3\envs\nlp\lib\site-packages (from flickrapi) (1.13.0)
# Collecting requests>=2.2.1
#   Using cached https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl
# Collecting oauthlib>=3.0.0
#   Using cached https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\nlp\lib\site-packages (from requests>=2.2.1->flickrapi) (2019.11.28)
# Collecting chardet<3.1.0,>=3.0.2
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\envs\nlp\lib\site-packages (from requests>=2.2.1->flickrapi) (1.25.8)
# Collecting idna<2.9,>=2.5
#   Using cached https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl
# Installing collected packages: chardet, idna, requests, oauthlib, requests-oauthlib, requests-toolbelt, flickrapi
# Successfully installed chardet-3.0.4 flickrapi-2.4.0 idna-2.8 oauthlib-3.1.0 requests-2.22.0 requests-oauthlib-1.3.0 requests-toolbelt-0.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from flickrapi import FlickrAPI

FLICKER_KEY = '505e8c2b05e8b5aa51766a43fc4bc7a7'
FLICKER_SECRET = '46b3ef2f43b04ac6'

flickr = FlickrAPI(FLICKER_KEY, FLICKER_SECRET, format='parsed-json')
extras='url_s'
# extras='url_sq,url_t,url_s,url_q,url_m,url_n,url_z,url_c,url_l,url_o'

cats = flickr.photos.search(text='kitten', per_page=100, extras='url_s')
photos = cats['photos']

from pprint import pprint
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 1805,
#  'perpage': 100,
#  'photo': [{'farm': 66,
#             'height_s': 203,
#             'id': '49491955921',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '185724874@N08',
#             'secret': '09eec5118a',
#             'server': '65535',
#             'title': 'Kitten and Frog(15)',
#             'url_s': 'https://live.staticflickr.com/65535/49491955921_09eec5118a_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492063487',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'e586c2ffc4',
#             'server': '65535',
#             'title': 'IMG_6181',
#             'url_s': 'https://live.staticflickr.com/65535/49492063487_e586c2ffc4_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 128,
#             'id': '49491852761',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '260ed6b604',
#             'server': '65535',
#             'title': 'IMG_6194',
#             'url_s': 'https://live.staticflickr.com/65535/49491852761_260ed6b604_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491351088',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '8070463@N03',
#             'secret': '21714bd4ba',
#             'server': '65535',
#             'title': 'Cute wildcat kitten exploring',
#             'url_s': 'https://live.staticflickr.com/65535/49491351088_21714bd4ba_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 134,
#             'id': '49491852261',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '328b3cc7ed',
#             'server': '65535',
#             'title': 'IMG_6195',
#             'url_s': 'https://live.staticflickr.com/65535/49491852261_328b3cc7ed_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491851826',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '3509f992a6',
#             'server': '65535',
#             'title': 'IMG_6212',
#             'url_s': 'https://live.staticflickr.com/65535/49491851826_3509f992a6_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491850956',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '6ca47ac2dc',
#             'server': '65535',
#             'title': 'IMG_6233',
#             'url_s': 'https://live.staticflickr.com/65535/49491850956_6ca47ac2dc_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491348743',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '4dd0375aa0',
#             'server': '65535',
#             'title': 'IMG_6238',
#             'url_s': 'https://live.staticflickr.com/65535/49491348743_4dd0375aa0_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491348198',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'f91fa5bfa1',
#             'server': '65535',
#             'title': 'IMG_6245',
#             'url_s': 'https://live.staticflickr.com/65535/49491348198_f91fa5bfa1_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492058977',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'a072b9a9ce',
#             'server': '65535',
#             'title': 'IMG_6248',
#             'url_s': 'https://live.staticflickr.com/65535/49492058977_a072b9a9ce_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492058362',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '321caede87',
#             'server': '65535',
#             'title': 'IMG_6259',
#             'url_s': 'https://live.staticflickr.com/65535/49492058362_321caede87_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491346238',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '804936c3c5',
#             'server': '65535',
#             'title': 'IMG_6285',
#             'url_s': 'https://live.staticflickr.com/65535/49491346238_804936c3c5_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491345653',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'e1bc5bea12',
#             'server': '65535',
#             'title': 'IMG_6293',
#             'url_s': 'https://live.staticflickr.com/65535/49491345653_e1bc5bea12_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491345093',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '74892a3acb',
#             'server': '65535',
#             'title': 'IMG_6491',
#             'url_s': 'https://live.staticflickr.com/65535/49491345093_74892a3acb_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491845866',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '91621dd387',
#             'server': '65535',
#             'title': 'IMG_6509',
#             'url_s': 'https://live.staticflickr.com/65535/49491845866_91621dd387_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492055112',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '0ffff450fe',
#             'server': '65535',
#             'title': 'IMG_6512',
#             'url_s': 'https://live.staticflickr.com/65535/49492055112_0ffff450fe_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491342798',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'ed724c2211',
#             'server': '65535',
#             'title': 'IMG_6515',
#             'url_s': 'https://live.staticflickr.com/65535/49491342798_ed724c2211_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492053652',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '8847d1fb53',
#             'server': '65535',
#             'title': 'IMG_6521',
#             'url_s': 'https://live.staticflickr.com/65535/49492053652_8847d1fb53_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492053017',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'e9ebc6db82',
#             'server': '65535',
#             'title': 'IMG_6559',
#             'url_s': 'https://live.staticflickr.com/65535/49492053017_e9ebc6db82_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491842341',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '4ba44e41db',
#             'server': '65535',
#             'title': 'IMG_6562',
#             'url_s': 'https://live.staticflickr.com/65535/49491842341_4ba44e41db_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491841441',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'cab6d9b0d9',
#             'server': '65535',
#             'title': 'IMG_5990',
#             'url_s': 'https://live.staticflickr.com/65535/49491841441_cab6d9b0d9_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492051107',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '31998148cc',
#             'server': '65535',
#             'title': 'IMG_6003',
#             'url_s': 'https://live.staticflickr.com/65535/49492051107_31998148cc_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491338888',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'a9e1bb2ecd',
#             'server': '65535',
#             'title': 'IMG_6032',
#             'url_s': 'https://live.staticflickr.com/65535/49491338888_a9e1bb2ecd_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491338318',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '41ceb09f4b',
#             'server': '65535',
#             'title': 'IMG_6041',
#             'url_s': 'https://live.staticflickr.com/65535/49491338318_41ceb09f4b_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491337748',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '3dddc318f2',
#             'server': '65535',
#             'title': 'IMG_6070',
#             'url_s': 'https://live.staticflickr.com/65535/49491337748_3dddc318f2_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491337038',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'f8f2318da5',
#             'server': '65535',
#             'title': 'IMG_6073',
#             'url_s': 'https://live.staticflickr.com/65535/49491337038_f8f2318da5_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492048122',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '6468d84de6',
#             'server': '65535',
#             'title': 'IMG_6078',
#             'url_s': 'https://live.staticflickr.com/65535/49492048122_6468d84de6_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491336068',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'e7ae3c628e',
#             'server': '65535',
#             'title': 'IMG_6085',
#             'url_s': 'https://live.staticflickr.com/65535/49491336068_e7ae3c628e_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492047012',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '664eca0368',
#             'server': '65535',
#             'title': 'IMG_6096',
#             'url_s': 'https://live.staticflickr.com/65535/49492047012_664eca0368_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491836211',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '27bddfab64',
#             'server': '65535',
#             'title': 'IMG_6103',
#             'url_s': 'https://live.staticflickr.com/65535/49491836211_27bddfab64_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49491334403',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '70cc1b0ee9',
#             'server': '65535',
#             'title': 'IMG_6113',
#             'url_s': 'https://live.staticflickr.com/65535/49491334403_70cc1b0ee9_m.jpg',
#             'width_s': 160},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491835436',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '7a2dbcb64f',
#             'server': '65535',
#             'title': 'IMG_6123',
#             'url_s': 'https://live.staticflickr.com/65535/49491835436_7a2dbcb64f_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491333378',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'c3d12a9703',
#             'server': '65535',
#             'title': 'IMG_6131',
#             'url_s': 'https://live.staticflickr.com/65535/49491333378_c3d12a9703_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491332828',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '8cd7e31f7f',
#             'server': '65535',
#             'title': 'IMG_6132',
#             'url_s': 'https://live.staticflickr.com/65535/49491332828_8cd7e31f7f_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491833911',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '9af07d2263',
#             'server': '65535',
#             'title': 'IMG_6138',
#             'url_s': 'https://live.staticflickr.com/65535/49491833911_9af07d2263_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491833501',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '79d940e59f',
#             'server': '65535',
#             'title': 'IMG_6139',
#             'url_s': 'https://live.staticflickr.com/65535/49491833501_79d940e59f_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492042862',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'fce485d8cd',
#             'server': '65535',
#             'title': 'IMG_6158',
#             'url_s': 'https://live.staticflickr.com/65535/49492042862_fce485d8cd_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491330428',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '3c34b42bb7',
#             'server': '65535',
#             'title': 'IMG_6160',
#             'url_s': 'https://live.staticflickr.com/65535/49491330428_3c34b42bb7_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491329768',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'b3e51a397f',
#             'server': '65535',
#             'title': 'IMG_6166',
#             'url_s': 'https://live.staticflickr.com/65535/49491329768_b3e51a397f_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49492040562',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': 'dfa6d89904',
#             'server': '65535',
#             'title': 'IMG_6167',
#             'url_s': 'https://live.staticflickr.com/65535/49492040562_dfa6d89904_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491328393',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186672597@N03',
#             'secret': '6dea95f327',
#             'server': '65535',
#             'title': 'IMG_6173',
#             'url_s': 'https://live.staticflickr.com/65535/49491328393_6dea95f327_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 146,
#             'id': '49488232351',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '77654185@N07',
#             'secret': '0ba5477193',
#             'server': '65535',
#             'title': 'Alexander Hamilton surprised me so much I almost stepped '
#                      'on him',
#             'url_s': 'https://live.staticflickr.com/65535/49488232351_0ba5477193_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491493671',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '153984403@N05',
#             'secret': 'dca646b85b',
#             'server': '65535',
#             'title': 'field kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49491493671_dca646b85b_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49491658062',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '70467489@N00',
#             'secret': 'e239a3d375',
#             'server': '65535',
#             'title': 'f80_122_11',
#             'url_s': 'https://live.staticflickr.com/65535/49491658062_e239a3d375_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49491437732',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '153984403@N05',
#             'secret': 'e9ff2ac836',
#             'server': '65535',
#             'title': 'Kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49491437732_e9ff2ac836_m.jpg',
#             'width_s': 160},
#            {'farm': 66,
#             'height_s': 128,
#             'id': '49491328832',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '8740272@N04',
#             'secret': '2fa8e54fb6',
#             'server': '65535',
#             'title': 'Happy Furry Wednesday ♥',
#             'url_s': 'https://live.staticflickr.com/65535/49491328832_2fa8e54fb6_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 181,
#             'id': '49491115277',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '65219625@N05',
#             'secret': '3aefda345a',
#             'server': '65535',
#             'title': 'DSC02801',
#             'url_s': 'https://live.staticflickr.com/65535/49491115277_3aefda345a_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 192,
#             'id': '49489877293',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '145114455@N02',
#             'secret': 'c123189e18',
#             'server': '65535',
#             'title': 'A Little Kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49489877293_c123189e18_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 180,
#             'id': '49490601577',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '123020986@N08',
#             'secret': 'f79493b5ae',
#             'server': '65535',
#             'title': 'Kittens ready to play',
#             'url_s': 'https://live.staticflickr.com/65535/49490601577_f79493b5ae_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49490381212',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '49998540@N03',
#             'secret': '86ca5150bc',
#             'server': '65535',
#             'title': 'すとーぶねこ #ねこ #猫 #cat #gatto #chat #kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49490381212_86ca5150bc_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49490199767',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '154605377@N08',
#             'secret': 'f78f93dde8',
#             'server': '65535',
#             'title': 'Persian Kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49490199767_f78f93dde8_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 180,
#             'id': '49489855622',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '45995313@N07',
#             'secret': '58409d2f18',
#             'server': '65535',
#             'title': 'Kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49489855622_58409d2f18_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 124,
#             'id': '49489531281',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '164850063@N02',
#             'secret': '10bc92445d',
#             'server': '65535',
#             'title': 'Spleen',
#             'url_s': 'https://live.staticflickr.com/65535/49489531281_10bc92445d_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49489511511',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '158784004@N07',
#             'secret': '48c9f5dfa6',
#             'server': '65535',
#             'title': 'Orange Tabby Cat Portrait in Studio and Wearing a Bow '
#                      'Tie',
#             'url_s': 'https://live.staticflickr.com/65535/49489511511_48c9f5dfa6_m.jpg',
#             'width_s': 160},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49489507152',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '185724874@N08',
#             'secret': '5541bd8962',
#             'server': '65535',
#             'title': 'Untitled(1)-1.bmp',
#             'url_s': 'https://live.staticflickr.com/65535/49489507152_5541bd8962_m.jpg',
#             'width_s': 185},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49489355577',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '151819983@N05',
#             'secret': '1866894dfd',
#             'server': '65535',
#             'title': 'dim465_elena_kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49489355577_1866894dfd_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 168,
#             'id': '49489000476',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': '190d5a89ea',
#             'server': '65535',
#             'title': 'Charles walking along the fence.',
#             'url_s': 'https://live.staticflickr.com/65535/49489000476_190d5a89ea_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 172,
#             'id': '49489208992',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': 'd972a119f3',
#             'server': '65535',
#             'title': 'Charles walking along the fence.',
#             'url_s': 'https://live.staticflickr.com/65535/49489208992_d972a119f3_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 180,
#             'id': '49489208712',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': '5a7cfec7e3',
#             'server': '65535',
#             'title': 'Charles.',
#             'url_s': 'https://live.staticflickr.com/65535/49489208712_5a7cfec7e3_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 208,
#             'id': '49488999516',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': '5233763d26',
#             'server': '65535',
#             'title': 'Fluff and William.',
#             'url_s': 'https://live.staticflickr.com/65535/49488999516_5233763d26_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 183,
#             'id': '49488999276',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': '264e594b42',
#             'server': '65535',
#             'title': 'Charles, Fluff and William.',
#             'url_s': 'https://live.staticflickr.com/65535/49488999276_264e594b42_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 174,
#             'id': '49488501713',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': 'b940f48b56',
#             'server': '65535',
#             'title': 'Charles, Fluff and William on the shed roof.',
#             'url_s': 'https://live.staticflickr.com/65535/49488501713_b940f48b56_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 198,
#             'id': '49488998726',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': 'a2473ae022',
#             'server': '65535',
#             'title': 'Charles, Fluff and William.',
#             'url_s': 'https://live.staticflickr.com/65535/49488998726_a2473ae022_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 159,
#             'id': '49489206727',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': 'c30594bf22',
#             'server': '65535',
#             'title': 'Charles, Fluff and William.',
#             'url_s': 'https://live.staticflickr.com/65535/49489206727_c30594bf22_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 174,
#             'id': '49489206312',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '41301592@N02',
#             'secret': '081b99f53e',
#             'server': '65535',
#             'title': 'Charles, Fluff and William.',
#             'url_s': 'https://live.staticflickr.com/65535/49489206312_081b99f53e_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49488181593',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '108166824@N05',
#             'secret': 'd6b27ca155',
#             'server': '65535',
#             'title': 'curious cat leaning',
#             'url_s': 'https://live.staticflickr.com/65535/49488181593_d6b27ca155_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 201,
#             'id': '49488312671',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '40453573@N00',
#             'secret': 'f0b7568c81',
#             'server': '65535',
#             'title': 'bundeltje kittens',
#             'url_s': 'https://live.staticflickr.com/65535/49488312671_f0b7568c81_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 180,
#             'id': '49488123017',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '181783830@N03',
#             'secret': '13b75d9f63',
#             'server': '65535',
#             'title': 'Lunar',
#             'url_s': 'https://live.staticflickr.com/65535/49488123017_13b75d9f63_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 180,
#             'id': '49487381158',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '181783830@N03',
#             'secret': '8d44aed23c',
#             'server': '65535',
#             'title': 'Lunar',
#             'url_s': 'https://live.staticflickr.com/65535/49487381158_8d44aed23c_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 150,
#             'id': '49488014332',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '141216898@N03',
#             'secret': 'e424fb9332',
#             'server': '65535',
#             'title': 'Art Class',
#             'url_s': 'https://live.staticflickr.com/65535/49488014332_e424fb9332_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49487694731',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '38941615@N02',
#             'secret': 'd9a6a181d9',
#             'server': '65535',
#             'title': 'Spritz',
#             'url_s': 'https://live.staticflickr.com/65535/49487694731_d9a6a181d9_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49487608422',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '156689344@N08',
#             'secret': 'e810fc14d5',
#             'server': '65535',
#             'title': 'Pet Veterinarian Services',
#             'url_s': 'https://live.staticflickr.com/65535/49487608422_e810fc14d5_m.jpg',
#             'width_s': 96},
#            {'farm': 66,
#             'height_s': 178,
#             'id': '49487576332',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '31984487@N00',
#             'secret': '0c2e0855a1',
#             'server': '65535',
#             'title': 'Halloween Surprise (Ashley Davis)',
#             'url_s': 'https://live.staticflickr.com/65535/49487576332_0c2e0855a1_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 111,
#             'id': '49487346382',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '141235261@N04',
#             'secret': 'b588b920c7',
#             'server': '65535',
#             'title': 'DSC_4476-Edit-3',
#             'url_s': 'https://live.staticflickr.com/65535/49487346382_b588b920c7_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 191,
#             'id': '49487085731',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186360156@N02',
#             'secret': '8da00d6161',
#             'server': '65535',
#             'title': 'Wherever the Marines land they find a pet and this '
#                      'Marine on Tarawa is no exception. After the heavy '
#                      'fighting died down he made friends with a kitten by '
#                      'sharing his water in the shade of a wrecked tank.',
#             'url_s': 'https://live.staticflickr.com/65535/49487085731_8da00d6161_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 135,
#             'id': '49486429798',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '141749824@N07',
#             'secret': '8319634243',
#             'server': '65535',
#             'title': '',
#             'url_s': 'https://live.staticflickr.com/65535/49486429798_8319634243_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49486766107',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '8740272@N04',
#             'secret': '7e35bdd948',
#             'server': '65535',
#             'title': 'Richard Sunbathing ☼ (21°C/69,8°F in February)',
#             'url_s': 'https://live.staticflickr.com/65535/49486766107_7e35bdd948_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49486030168',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '26999357@N07',
#             'secret': 'd9183087f0',
#             'server': '65535',
#             'title': 'Мечтатель',
#             'url_s': 'https://live.staticflickr.com/65535/49486030168_d9183087f0_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 180,
#             'id': '49486462661',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '9817122@N05',
#             'secret': '8b47a0e515',
#             'server': '65535',
#             'title': 'Eyes of Gold',
#             'url_s': 'https://live.staticflickr.com/65535/49486462661_8b47a0e515_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49485898713',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186115925@N03',
#             'secret': '3df174d8d0',
#             'server': '65535',
#             'title': 'Responsible Kitten Transportation',
#             'url_s': 'https://live.staticflickr.com/65535/49485898713_3df174d8d0_m.jpg',
#             'width_s': 209},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49486352471',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '143537090@N02',
#             'secret': 'ee3f1f02ab',
#             'server': '65535',
#             'title': 'Siamese Cats',
#             'url_s': 'https://live.staticflickr.com/65535/49486352471_ee3f1f02ab_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49486123657',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186115925@N03',
#             'secret': 'cf1a162ee1',
#             'server': '65535',
#             'title': 'Responsible Kitten Transportation',
#             'url_s': 'https://live.staticflickr.com/65535/49486123657_cf1a162ee1_m.jpg',
#             'width_s': 209},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49485401608',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '155000122@N02',
#             'secret': '8d96b0402d',
#             'server': '65535',
#             'title': 'kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49485401608_8d96b0402d_m.jpg',
#             'width_s': 176},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49485099873',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '49998540@N03',
#             'secret': 'db1a871813',
#             'server': '65535',
#             'title': 'まくらねるねこ #ねこ #猫 #cat #gatto #chat #kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49485099873_db1a871813_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49485107401',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '22419581@N06',
#             'secret': 'c1b46c92b1',
#             'server': '65535',
#             'title': 'A year ago today we said farewell to Casper Creamsickle '
#                      'Flump, Esq. (a/k/a Spud and too many other names to '
#                      'list). Time heals, kittens help. Luna Moonshadow (a/k/a '
#                      "Googie) doesn't nap in cat beds, she prefers hard "
#                      'surfaces; glass tables, ceramic floors, w',
#             'url_s': 'https://live.staticflickr.com/65535/49485107401_c1b46c92b1_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49485250602',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '146375971@N04',
#             'secret': 'bebbd8a5d5',
#             'server': '65535',
#             'title': 'Me and my Little Girl',
#             'url_s': 'https://live.staticflickr.com/65535/49485250602_bebbd8a5d5_m.jpg',
#             'width_s': 128},
#            {'farm': 66,
#             'height_s': 191,
#             'id': '49484837282',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '128184123@N04',
#             'secret': '7f30d091ed',
#             'server': '65535',
#             'title': 'AMARA BEAUTY Jana',
#             'url_s': 'https://live.staticflickr.com/65535/49484837282_7f30d091ed_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49483917918',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186709747@N07',
#             'secret': '7578c39b6f',
#             'server': '65535',
#             'title': 'Bedroom Kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49483917918_7578c39b6f_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49484613872',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186709747@N07',
#             'secret': '462e5090d5',
#             'server': '65535',
#             'title': 'Play Room Kitten - By Yuuki Bookmite',
#             'url_s': 'https://live.staticflickr.com/65535/49484613872_462e5090d5_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 192,
#             'id': '49484606092',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186709747@N07',
#             'secret': '393e32ec63',
#             'server': '65535',
#             'title': 'Kitten Dancer',
#             'url_s': 'https://live.staticflickr.com/65535/49484606092_393e32ec63_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 192,
#             'id': '49484606067',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186709747@N07',
#             'secret': '72bfe2b931',
#             'server': '65535',
#             'title': 'Kitten Dancer',
#             'url_s': 'https://live.staticflickr.com/65535/49484606067_72bfe2b931_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 149,
#             'id': '49483645348',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '146250009@N06',
#             'secret': 'e8bfb1e6fd',
#             'server': '65535',
#             'title': 'litle naughty kitten',
#             'url_s': 'https://live.staticflickr.com/65535/49483645348_e8bfb1e6fd_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 157,
#             'id': '49483537603',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '68432253@N04',
#             'secret': '221b1249cb',
#             'server': '65535',
#             'title': '50p Coin 2017 Tom Kitten Circulated FREEPOST Beatrix '
#                      'Potter  item number 323831644458 by sweden_2005 on Ebay '
#                      'Using Our Copyright Photo',
#             'url_s': 'https://live.staticflickr.com/65535/49483537603_221b1249cb_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 192,
#             'id': '49484226617',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '32029534@N00',
#             'secret': 'fb806ee094',
#             'server': '65535',
#             'title': 'tiger arrives with his giant paws, scott richard',
#             'url_s': 'https://live.staticflickr.com/65535/49484226617_fb806ee094_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49483820256',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '8185859@N08',
#             'secret': '7d00ae314e',
#             'server': '65535',
#             'title': 'Lilli',
#             'url_s': 'https://live.staticflickr.com/65535/49483820256_7d00ae314e_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 240,
#             'id': '49483144768',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '142387828@N02',
#             'secret': '940ecf2db6',
#             'server': '65535',
#             'title': "My Cat Wanted To Say ''Hi'' To you all",
#             'url_s': 'https://live.staticflickr.com/65535/49483144768_940ecf2db6_m.jpg',
#             'width_s': 185},
#            {'farm': 66,
#             'height_s': 183,
#             'id': '49483811417',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '21196830@N04',
#             'secret': '669db1da2a',
#             'server': '65535',
#             'title': 'SHADCURTAINS1980',
#             'url_s': 'https://live.staticflickr.com/65535/49483811417_669db1da2a_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 175,
#             'id': '49483113818',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '21196830@N04',
#             'secret': 'c496cc0242',
#             'server': '65535',
#             'title': 'SHADCURTAINSLAY',
#             'url_s': 'https://live.staticflickr.com/65535/49483113818_c496cc0242_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49483554366',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '23848107@N07',
#             'secret': '527e29d47c',
#             'server': '65535',
#             'title': '2020-02-02 FS 01',
#             'url_s': 'https://live.staticflickr.com/65535/49483554366_527e29d47c_m.jpg',
#             'width_s': 240},
#            {'farm': 66,
#             'height_s': 160,
#             'id': '49483489126',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '12615324@N03',
#             'secret': 'b00763b65b',
#             'server': '65535',
#             'title': 'Hanoi Mono',
#             'url_s': 'https://live.staticflickr.com/65535/49483489126_b00763b65b_m.jpg',
#             'width_s': 240}],
#  'total': '180425'}

# %%
# import the necessary packages
import numpy as np
import urllib
import cv2

# url을 이미지로 변경하는 함수
def url_to_image(url):
    resp = urllib.request.urlopen(url)
    image = np.asarray(bytearray(resp.read()), dtype='uint8')
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)

# %%
# from google.colab.patches import cv2_imshow   # 구글 colab에서 사용
import cv2   # 맞나?

# initialize the list of image URLs to download
urls = [
	"https://live.staticflickr.com/65535/48239557012_4408050887_m.jpg",
    "https://live.staticflickr.com/65535/48239467791_c85039d01f_m.jpg"
]

for url in urls:
    print('download:', url)
    image = url_to_image(url)
    cv2.imshow('image', image)
# Out:
# download: https://live.staticflickr.com/65535/48239557012_4408050887_m.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-15-70441a0aaaae> in <module>
#      11     print('download:', url)
#      12     image = url_to_image(url)
# ---> 13     cv2.imshow('image', image)
#      14
#
# error: OpenCV(4.1.2) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from google.colab.patches import cv2_imshow

# %%
print image_temp.shape
# Out:
# (160, 240, 3)

# %%
def image_resize(image, x, y):
  return cv2.resize(image, (x, y))

# %%
resized = image_resize(image_temp, 224, 224)

# %%
print resized.shape
cv2_imshow(resized)
# Out:
# (224, 224, 3)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F2E3CC30BD0>

# %%
resized = np.expand_dims(resized, axis=0)

# %%
print resized.shape
# Out:
# (1, 224, 224, 3)

# %%
cv2_imshow(np.squeeze(resized))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F2E3CC301D0>
